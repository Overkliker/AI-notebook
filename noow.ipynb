# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

ds = pd.read_csv(r'C:\Users\kliker\Desktop\IMOEX_240331_240401.csv', delimiter=';')

ds.head(5)
# Out:
#   <TICKER>  <PER>  <DATE>  <TIME>   <OPEN>   <HIGH>    <LOW>  <CLOSE>  \
# 0    IMOEX     60  240401  100000  3344.78  3361.26  3344.23  3359.67
# 1    IMOEX     60  240401  110000  3359.56  3364.16  3357.64  3357.99
# 2    IMOEX     60  240401  120000  3358.21  3363.33  3358.09  3358.64
# 3    IMOEX     60  240401  130000  3358.65  3361.79  3355.17  3355.86
# 4    IMOEX     60  240401  140000  3355.95  3358.07  3355.73  3356.84
#
#          <VOL>
# 0  23600306902
# 1  11184367722
# 2  11339315749
# 3  12188445828
# 4   6217021614

# %%
x = ds['<CLOSE>']
y = ds['<TIME>']

print(x)
print(y)
# Out:
# 0    3359.67
# 1    3357.99
# 2    3358.64
# 3    3355.86
# 4    3356.84
# Name: <CLOSE>, dtype: float64
# 0    100000
# 1    110000
# 2    120000
# 3    130000
# 4    140000
# Name: <TIME>, dtype: int64

# %%
fig, ax = plt.subplots()
ax.stairs(y, linewidth=2.5)
plt.show()

# %% [markdown]
# Stairs plot

# %%
fig, ax = plt.subplots()
ax.ecdf(x)
plt.show()

# %%
fig, ax = plt.subplots()

ax.stem(x, y)
plt.show()
